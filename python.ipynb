# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('output/test.csv', header=None, names=['year','gender','name','count'])
df
# Out:
#         year  gender       name  count
# 0       1944  female   MARGARET    341
# 1       1944  female      HELEN    209
# 2       1944  female     JUDITH    189
# 3       1944  female   PATRICIA    186
# 4       1944  female     PAMELA    160
# 5       1944  female  ELIZABETH    153
# 6       1944  female   JENNIFER    149
# 7       1944  female    BARBARA    147
# 8       1944  female   LORRAINE    143
# 9       1944  female  CHRISTINE    135
# 10      1944  female   BEVERLEY    114
# 11      1944  female     JANICE    107
# 12      1944  female     SANDRA    107
# 13      1944  female    LYNETTE    106
# 14      1944  female    JILLIAN     98
# 15      1944  female      JANET     97
# 16      1944  female       MARY     96
# 17      1944  female    HEATHER     94
# 18      1944  female    SHIRLEY     93
# 19      1944  female    RAELENE     81
# 20      1944  female   ROSEMARY     78
# 21      1944  female    PAULINE     77
# 22      1944  female      WENDY     73
# ...

# %%
df.dtypes
# Out:
# year       int64
# gender    object
# name      object
# count      int64
# dtype: object

# %%
df['gender'] = df['gender'].astype('category')
# df['name'] = df['name'].astype('string')
df.dtypes
# Out:
# year         int64
# gender    category
# name        object
# count        int64
# dtype: object

# %%
pd.pivot_table(df, values='count', columns=['year'], index=['gender','name'])
# Out:
# year                         1944  1945  1946  1947  1948  1949  1950  1951  \
# gender name
# female 'AISYAH                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        'PIAF'                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        'UHEINA-'I-LANGIMA'A   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        (NOT                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        ?LIAM                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        A                      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        A'AFF                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        A'ARON                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        A'DELE                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        A'ISHA                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#        A'ISHAH                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...
